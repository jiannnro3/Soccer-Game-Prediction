# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load CSV file into a DataFrame
file_path = '/content/Soccer_Data.csv'  # Adjust the file path as needed
matches = pd.read_csv(file_path)

# %%
matches.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away
# 1           1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home
# 2           2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away
# 3           3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home
# 4           4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away
#
#   result   gf   ga  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0      D  1.0  1.0  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1      W  3.0  1.0  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2      W  2.0  1.0  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3      W  3.0  0.0  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4      W  3.0  1.0  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#   season       team
# 0   2022  Liverpool
# 1   2022  Liverpool
# 2   2022  Liverpool
# 3   2022  Liverpool
# 4   2022  Liverpool
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (1296, 28)

# %%
matches["team"].value_counts()
# Out:
# Liverpool                   65
# Brighton and Hove Albion    65
# Nottingham Forest           65
# Everton                     65
# Brentford                   65
# Crystal Palace              65
# Manchester City             65
# Wolverhampton Wanderers     65
# Fulham                      65
# Newcastle United            65
# West Ham United             65
# Manchester United           65
# Aston Villa                 65
# Arsenal                     65
# Chelsea                     64
# Bournemouth                 64
# Tottenham Hotspur           64
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Burnley                     27
# Sheffield United            27
# Luton Town                  26
# Name: team, dtype: int64

# %%
matches.dtypes
# Out:
# Unnamed: 0        int64
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_num"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_num"] = matches["opponent"].astype("category").cat.codes

# %%
##matches["ref_num"] = matches["referee"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_num"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#       Unnamed: 0       date   time            comp         round  day venue  \
# 0              0 2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away
# 1              1 2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home
# 2              2 2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away
# 3              3 2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home
# 4              4 2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away
# ...          ...        ...    ...             ...           ...  ...   ...
# 1291          42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away
# 1292          43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away
# 1293          44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home
# 1294          45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away
# 1295          46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home
#
#      result   gf   ga  ... pk  pkatt  season         team  venue_num opp_num  \
# 0         D  1.0  1.0  ...  0      0    2022    Liverpool          0       6
# 1         W  3.0  1.0  ...  0      1    2022    Liverpool          1       2
# 2         W  2.0  1.0  ...  0      0    2022    Liverpool          0      16
# 3         W  3.0  0.0  ...  0      0    2022    Liverpool          1       1
# 4         W  3.0  1.0  ...  0      0    2022    Liverpool          0      22
# ...     ...  ...  ...  ... ..    ...     ...          ...        ...     ...
# 1291      L  1.0  3.0  ...  0      0    2021  Southampton          0      16
# 1292      L  3.0  4.0  ...  1      1    2021  Southampton          0      17
# 1293      L  0.0  2.0  ...  0      0    2021  Southampton          1       9
# 1294      L  1.0  3.0  ...  0      0    2021  Southampton          0       4
# 1295      D  4.0  4.0  ...  0      0    2021  Southampton          1      12
#
#      hour day_num ref_num  target
# 0      16       6       2       0
# 1      15       5      24       1
# 2      16       6      10       1
# 3      14       6      22       1
# 4      12       5      13       1
# ...   ...     ...     ...     ...
# 1291   14       6       2       0
# 1292   20       0      13       0
# 1293   15       5      24       0
# 1294   14       6      15       0
# 1295   16       6       6       0
#
# [1296 rows x 34 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_num", "opp_num", "hour", "day_num"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.5915492957746479

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          64  24
# 1          34  20

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.45454545454545453

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#      Unnamed: 0       date   time            comp         round  day venue  \
# 539           4 2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home
# 540           5 2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# 541           6 2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away
# 542           9 2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away
# 543          10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home
# ..          ...        ...    ...             ...           ...  ...   ...
# 49           33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home
# 50           35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home
# 51           36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home
# 52           37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away
# 53           39 2024-03-03  15:30  Premier League  Matchweek 27  Sun  Home
#
#     result   gf   ga  ... ref_num  target  gf_rolling  ga_rolling  sh_rolling  \
# 539      W  4.0  2.0  ...       6       1    3.000000    1.000000   17.666667
# 540      W  6.0  0.0  ...      15       1    3.666667    1.666667   19.333333
# 541      D  1.0  1.0  ...      22       0    4.333333    1.666667   18.666667
# 542      W  3.0  0.0  ...       2       1    3.666667    1.000000   16.000000
# 543      W  6.0  3.0  ...      13       1    3.333333    0.333333   15.333333
# ..     ...  ...  ...  ...     ...     ...         ...         ...         ...
# 49       W  2.0  0.0  ...      10       1    3.000000    1.333333   22.000000
# 50       D  1.0  1.0  ...       1       0    2.666667    0.666667   19.333333
# 51       W  1.0  0.0  ...       6       1    2.000000    0.666667   25.000000
# 52       W  1.0  0.0  ...       9       1    1.333333    0.333333   25.000000
# 53       W  3.0  1.0  ...       1       1    1.000000    0.333333   23.666667
#
#     sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 539    6.000000    17.466667   0.666667   0.333333       0.333333
# 540    7.333333    15.933333   0.333333   0.000000       0.000000
# 541    8.000000    15.033333   0.333333   0.000000       0.000000
# 542    6.000000    15.233333   0.333333   0.000000       0.000000
# 543    6.666667    17.000000   0.333333   0.000000       0.000000
# ..          ...          ...        ...        ...            ...
# 49    10.000000    18.100000   1.000000   0.000000       0.000000
# 50     7.333333    17.466667   0.333333   0.000000       0.000000
# 51     7.666667    17.500000   0.333333   0.000000       0.000000
# 52     6.000000    16.966667   0.333333   0.000000       0.000000
# 53     7.000000    16.333333   0.666667   0.000000       0.000000
#
# [62 rows x 42 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                              Unnamed: 0       date   time            comp  \
# team
# Arsenal                 577           3 2022-08-27  17:30  Premier League
#                         578           4 2022-08-31  19:30  Premier League
#                         579           5 2022-09-04  16:30  Premier League
#                         580           7 2022-09-18  12:00  Premier League
#                         581           8 2022-10-01  12:30  Premier League
# ...                                 ...        ...    ...             ...
# Wolverhampton Wanderers 264          27 2024-02-04  14:00  Premier League
#                         265          28 2024-02-10  15:00  Premier League
#                         266          29 2024-02-17  15:00  Premier League
#                         267          30 2024-02-25  13:30  Premier League
#                         268          32 2024-03-02  15:00  Premier League
#
#                                     round  day venue result   gf   ga  ...  \
# team                                                                   ...
# Arsenal                 577   Matchweek 4  Sat  Home      W  2.0  1.0  ...
#                         578   Matchweek 5  Wed  Home      W  2.0  1.0  ...
#                         579   Matchweek 6  Sun  Away      L  1.0  3.0  ...
#                         580   Matchweek 8  Sun  Away      W  3.0  0.0  ...
#                         581   Matchweek 9  Sat  Home      W  3.0  1.0  ...
# ...                                   ...  ...   ...    ...  ...  ...  ...
# Wolverhampton Wanderers 264  Matchweek 23  Sun  Away      W  4.0  2.0  ...
#                         265  Matchweek 24  Sat  Home      L  0.0  2.0  ...
#                         266  Matchweek 25  Sat  Away      W  2.0  1.0  ...
#                         267  Matchweek 26  Sun  Home      W  1.0  0.0  ...
#                         268  Matchweek 27  Sat  Away      L  0.0  3.0  ...
#
#                             ref_num  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 577       9       1    3.000000    0.666667
#                         578      18       1    3.000000    1.000000
#                         579      15       0    2.333333    0.666667
#                         580       7       1    1.666667    1.666667
#                         581       2       1    2.000000    1.333333
# ...                             ...     ...         ...         ...
# Wolverhampton Wanderers 264      25       1    2.000000    1.333333
#                         265      22       0    2.333333    2.000000
#                         266       2       1    2.333333    2.666667
#                         267       5       1    2.000000    1.666667
#                         268      25       0    1.000000    1.000000
#
#                              sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 577   14.333333    5.000000    14.133333   0.333333
#                         578   18.333333    7.000000    14.433333   0.333333
#                         579   19.333333    7.333333    15.533333   0.666667
#                         580   20.000000    6.333333    16.800000   1.000000
#                         581   17.000000    6.000000    17.700000   0.666667
# ...                                 ...         ...          ...        ...
# Wolverhampton Wanderers 264   11.666667    4.666667    16.200000   0.333333
#                         265   12.000000    4.666667    17.266667   1.000000
#                         266   15.000000    5.333333    16.800000   1.333333
#                         267   14.000000    6.000000    16.566667   1.000000
#                         268   14.000000    4.666667    15.900000   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 577   0.000000       0.000000
#                         578   0.000000       0.000000
#                         579   0.000000       0.000000
#                         580   0.000000       0.000000
#                         581   0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 264   0.333333       0.333333
#                         265   0.666667       0.666667
#                         266   0.666667       0.666667
#                         267   0.333333       0.333333
#                         268   0.000000       0.000000
#
# [1227 rows x 42 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#      Unnamed: 0       date   time            comp         round  day venue  \
# 577           3 2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home
# 578           4 2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# 579           5 2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away
# 580           7 2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away
# 581           8 2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home
# ..          ...        ...    ...             ...           ...  ...   ...
# 264          27 2024-02-04  14:00  Premier League  Matchweek 23  Sun  Away
# 265          28 2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home
# 266          29 2024-02-17  15:00  Premier League  Matchweek 25  Sat  Away
# 267          30 2024-02-25  13:30  Premier League  Matchweek 26  Sun  Home
# 268          32 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away
#
#     result   gf   ga  ... ref_num  target  gf_rolling  ga_rolling  sh_rolling  \
# 577      W  2.0  1.0  ...       9       1    3.000000    0.666667   14.333333
# 578      W  2.0  1.0  ...      18       1    3.000000    1.000000   18.333333
# 579      L  1.0  3.0  ...      15       0    2.333333    0.666667   19.333333
# 580      W  3.0  0.0  ...       7       1    1.666667    1.666667   20.000000
# 581      W  3.0  1.0  ...       2       1    2.000000    1.333333   17.000000
# ..     ...  ...  ...  ...     ...     ...         ...         ...         ...
# 264      W  4.0  2.0  ...      25       1    2.000000    1.333333   11.666667
# 265      L  0.0  2.0  ...      22       0    2.333333    2.000000   12.000000
# 266      W  2.0  1.0  ...       2       1    2.333333    2.666667   15.000000
# 267      W  1.0  0.0  ...       5       1    2.000000    1.666667   14.000000
# 268      L  0.0  3.0  ...      25       0    1.000000    1.000000   14.000000
#
#     sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 577    5.000000    14.133333   0.333333   0.000000       0.000000
# 578    7.000000    14.433333   0.333333   0.000000       0.000000
# 579    7.333333    15.533333   0.666667   0.000000       0.000000
# 580    6.333333    16.800000   1.000000   0.000000       0.000000
# 581    6.000000    17.700000   0.666667   0.000000       0.000000
# ..          ...          ...        ...        ...            ...
# 264    4.666667    16.200000   0.333333   0.333333       0.333333
# 265    4.666667    17.266667   1.000000   0.666667       0.666667
# 266    5.333333    16.800000   1.333333   0.666667       0.666667
# 267    6.000000    16.566667   1.000000   0.333333       0.333333
# 268    4.666667    15.900000   0.333333   0.000000       0.000000
#
# [1227 rows x 42 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.6153846153846154
